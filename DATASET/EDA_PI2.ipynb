# %% [markdown]
# # <h1 align=center> **PROYECTO INDIVIDUAL N°2 (EDA)** </h1>

# %%
# Convoco librerias.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import gmaps
import gmaps.datasets
import numpy as np

# %% [markdown]
# # Importo los datasets para iniciar el analisis.

# %%
# Cargo los  archivos CSV en un DataFrame.
df_siniestros_hechos = pd.read_csv(r"D:\Users\Arnaldo\Desktop\SISTEMAS\SOYHENRY\CURSO\PROYECTOS\PROYECTO INDIVIDUAL II\DATASETS\df_siniestros_hechos.csv")
df_siniestros_victimas = pd.read_csv(r"D:\Users\Arnaldo\Desktop\SISTEMAS\SOYHENRY\CURSO\PROYECTOS\PROYECTO INDIVIDUAL II\DATASETS\df_siniestros_victimas.csv")

# %%
print(df_siniestros_hechos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     696 non-null    object
#  1   n_victimas             696 non-null    int64
#  2   fecha                  696 non-null    object
#  3   hh                     695 non-null    float64
#  4   tipo_de_calle          696 non-null    object
#  5   dirección normalizada  688 non-null    object
#  6   comuna                 696 non-null    int64
#  7   longitud               684 non-null    float64
#  8   latitud                684 non-null    float64
#  9   victima                696 non-null    object
#  10  acusado                696 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 59.9+ KB
# None

# %%
# Unifico los DataFrames usando el campo en común 'id'.
df_siniestros = pd.merge(df_siniestros_hechos, df_siniestros_victimas, on='id', how='inner')

# Corrijo tipo de variable en campo "HH".

# Reemplazo los valores no válidos (NaN o inf) en el campo 'hh' con un valor específico, por ejemplo, -1.
df_siniestros['hh'].fillna(-1, inplace=True)

# Convierto el campo 'hh' a tipo entero.
df_siniestros['hh'] = df_siniestros['hh'].astype(int)
# Identifico y tratar valores no finitos.
df_siniestros['edad'] = pd.to_numeric(df_siniestros['edad'], errors='coerce')

df_siniestros['edad'].fillna(0, inplace=True)

df_siniestros['edad'] = df_siniestros['edad'].astype(int)

df_siniestros.drop(columns=['fecha_fallecimiento'], inplace=True)
df_siniestros.drop(columns=['fecha_y'], inplace=True)
df_siniestros.rename(columns={'fecha_x': 'fecha'}, inplace=True)
df_siniestros.rename(columns={'victima_x': 'victima_1'}, inplace=True)
df_siniestros.rename(columns={'victima_y': 'victima_2'}, inplace=True)
df_siniestros.rename(columns={'hh':'hora'}, inplace=True)

df_siniestros.head()
# Out:
#           id  n_victimas       fecha  hora tipo_de_calle  \
# 0  2016-0001           1  2016-01-01     4       avenida
# 1  2016-0002           1  2016-01-02     1     autopista
# 2  2016-0003           1  2016-01-03     7       avenida
# 3  2016-0004           1  2016-01-10     0       avenida
# 4  2016-0005           1  2016-01-21     5       avenida
#
#                                dirección normalizada  comuna   longitud  \
# 0  piedra buena av. y fernandez de la cruz, f., g...       8 -58.475340
# 1               paz, gral. av. y de los corrales av.       9 -58.508775
# 2                                entre rios av. 2034       1 -58.390403
# 3          larrazabal av. y villegas, conrado, gral.       8 -58.465039
# 4            san juan av. y saenz peã‘a, luis, pres.       1 -58.387183
#
#      latitud victima_1    acusado        rol victima_2       sexo  edad
# 0 -34.687570      moto       auto  conductor      moto  masculino    19
# 1 -34.669777      auto  pasajeros  conductor      auto  masculino    70
# 2 -34.631894      moto       auto  conductor      moto  masculino    30
# 3 -34.680930      moto         sd  conductor      moto  masculino    18
# 4 -34.622466      moto  pasajeros  conductor      moto  masculino    29

# %%
df_siniestros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     717 non-null    object
#  1   n_victimas             717 non-null    int64
#  2   fecha                  717 non-null    object
#  3   hora                   717 non-null    int32
#  4   tipo_de_calle          717 non-null    object
#  5   dirección normalizada  708 non-null    object
#  6   comuna                 717 non-null    int64
#  7   longitud               704 non-null    float64
#  8   latitud                704 non-null    float64
#  9   victima_1              717 non-null    object
#  10  acusado                717 non-null    object
#  11  rol                    706 non-null    object
#  12  victima_2              708 non-null    object
#  13  sexo                   711 non-null    object
#  14  edad                   717 non-null    int32
# dtypes: float64(2), int32(2), int64(2), object(9)
# memory usage: 78.6+ KB

# %%
# Guardo el dataset unificado.
df_siniestros.to_csv(r'D:\Users\Arnaldo\Desktop\SISTEMAS\SOYHENRY\CURSO\PROYECTOS\PROYECTO INDIVIDUAL II\DATASETS\df_siniestros.csv', index=False)

# %% [markdown]
# ## Exploración de valores faltantes

# %%
# Determino porcentaje de valores faltantes en df "hechos".

total_nan_percentage = (df_siniestros.isna().sum().sum() / df_siniestros.size) * 100

# Creo el gráfico de torta.
plt.figure(figsize=(8, 6))
plt.pie([total_nan_percentage, 100 - total_nan_percentage],
        labels=['Valores NaN', 'Valores no NaN'],
        autopct='%1.1f%%',
        startangle=140)
plt.title('Porcentaje total de valores NaN en el DataFrame "Hechos"')
plt.axis('equal') 
plt.show()

# %% [markdown]
# ##### como se puede apreciar en el grafico de torta los valores nulos representan monos de medi punto. En consecuencia podemos trabajar con este dataframe con la tranquilidad de que los nulos no representan un sesgo en nuestro analisis.

# %%
# Calculo la suma total de NaN por columna.
nan_counts = df_siniestros.isna().sum()

# Sumar también los valores -1
nan_counts += (df_siniestros == -1).sum()

# Ordenar los campos de menor a mayor
nan_counts_sorted = nan_counts.sort_values()

# Creo una lista de colores
colors = ['blue' if val == 0 else 'maroon' for val in nan_counts_sorted]

# Creo el gráfico de barras horizontales.
plt.barh(range(len(nan_counts_sorted)), nan_counts_sorted, color=colors)

# Configuro el título y las etiquetas de los ejes.
plt.yticks(range(len(nan_counts_sorted)), nan_counts_sorted.index)
plt.xlabel('Número de NaN')
plt.ylabel('Campos')
plt.title('Cantidad de NaN por campos en df "Siniestros" (ordenado de mayor a menor).')

# Muestro el gráfico
plt.show()

# %% [markdown]
# ##### En este grafico se puede apreciar los campos mas afectados por los nulos.

# %% [markdown]
# ## Exploración de valores atípicos/extremos (outliers)

# %%
import matplotlib.pyplot as plt

# Conteo de valores únicos en todas las columnas de df_siniestros.
value_counts = df_siniestros.apply(lambda x: x.value_counts().count())

# Visualización de los conteos de valores únicos en un gráfico de torta.
plt.figure(figsize=(8, 6))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Conteo de Valores Únicos en df_siniestros')
plt.show()

# Conclusiones para df_siniestros.
print("Conclusión para df_siniestros:")
print("El gráfico de torta muestra el conteo de valores únicos en cada columna de df_siniestros.")
print("Esto proporciona una visión general de la variabilidad de los datos en cada variable.")
# Out:
# Conclusión para df_siniestros:
# El gráfico de torta muestra el conteo de valores únicos en cada columna de df_siniestros.
# Esto proporciona una visión general de la variabilidad de los datos en cada variable.

# %%
# Método de los cuartiles (IQR) para detectar outliers en df_siniestros
Q1_hechos = df_siniestros["n_victimas"].quantile(0.25)
Q3_hechos = df_siniestros["n_victimas"].quantile(0.75)
IQR_hechos = Q3_hechos - Q1_hechos

# Definir los límites para identificar los outliers.
lower_bound_hechos = Q1_hechos - 1.5 * IQR_hechos
upper_bound_hechos = Q3_hechos + 1.5 * IQR_hechos

# Filtrar los outliers en df_siniestros.
outliers_hechos = df_siniestros[(df_siniestros["n_victimas"] < lower_bound_hechos) | (df_siniestros["n_victimas"] > upper_bound_hechos)]

# Método de los cuartiles (IQR) para detectar outliers en df_siniestros.
Q1_victimas = df_siniestros["edad"].quantile(0.25)
Q3_victimas = df_siniestros["edad"].quantile(0.75)
IQR_victimas = Q3_victimas - Q1_victimas

# Definir los límites para identificar los outliers.
lower_bound_victimas = Q1_victimas - 1.5 * IQR_victimas
upper_bound_victimas = Q3_victimas + 1.5 * IQR_victimas

# Filtro los outliers en df_siniestros.
outliers_victimas = df_siniestros[(df_siniestros["edad"] < lower_bound_victimas) | (df_siniestros["edad"] > upper_bound_victimas)]

# Imprimo los resultados
print("Outliers en df_siniestros:")
print(outliers_hechos)
print("\nOutliers en df_siniestros:")
print(outliers_victimas)
# Out:
# Outliers en df_siniestros:
#             id  n_victimas       fecha  hora tipo_de_calle  \
# 29   2016-0041           2  2016-03-29    11       avenida
# 30   2016-0041           2  2016-03-29    11       avenida
# 98   2016-0126           2  2016-09-18    22         calle
# 99   2016-0126           2  2016-09-18    22         calle
# 163  2017-0026           2  2017-02-26     5       avenida
# 164  2017-0026           2  2017-02-26     5       avenida
# 173  2017-0035           3  2017-03-23     5       avenida
# 174  2017-0035           3  2017-03-23     5       avenida
# 175  2017-0035           3  2017-03-23     5       avenida
# 176  2017-0036           2  2017-03-29    18     autopista
# 177  2017-0036           2  2017-03-29    18     autopista
# 186  2017-0050           2  2017-04-28    11     autopista
# 187  2017-0050           2  2017-04-28    11     autopista
# 237  2017-0108           2  2017-09-02     4     autopista
# 238  2017-0108           2  2017-09-02     4     autopista
# 242  2017-0112           2  2017-09-10     9     autopista
# 243  2017-0112           2  2017-09-10     9     autopista
# 253  2017-0126           2  2017-10-14     6       avenida
# 254  2017-0126           2  2017-10-14     6       avenida
# 277  2017-0153           2  2017-12-11     2       avenida
# 278  2017-0153           2  2017-12-11     2       avenida
# 300  2018-0015           2  2018-02-06     1       avenida
# 301  2018-0015           2  2018-02-06     1       avenida
# 312  2018-0026           2  2018-03-09     4       avenida
# 313  2018-0026           2  2018-03-09     4       avenida
# 325  2018-0038           2  2018-04-20    17       avenida
# 326  2018-0038           2  2018-04-20    17       avenida
# 373  2018-0085           2  2018-08-03    18       avenida
# 374  2018-0085           2  2018-08-03    18       avenida
# 387  2018-0098           2  2018-09-09     5     autopista
# 388  2018-0098           2  2018-09-09     5     autopista
# 418  2018-0128           2  2018-11-25     4     autopista
# 419  2018-0128           2  2018-11-25     4     autopista
# 444  2019-0010           2  2019-02-02     7       avenida
# 445  2019-0010           2  2019-02-02     7       avenida
# 576  2020-0038           2  2020-08-30     4       avenida
# 577  2020-0038           2  2020-08-30     4       avenida
# 602  2020-0063           2  2020-12-05     7         calle
# 603  2020-0063           2  2020-12-05     7         calle
# 616  2020-0077           2  2020-12-25     6       avenida
# 617  2020-0077           2  2020-12-25     6       avenida
#
#                                  dirección normalizada  comuna   longitud  \
# 29                 directorio av. y rivera indarte av.       7 -58.460766
# 30                 directorio av. y rivera indarte av.       7 -58.460766
# 98                                irigoyen y tinogasta      10 -58.525721
# 99                                irigoyen y tinogasta      10 -58.525721
# 163                      moreno, perito av. y fournier       4 -58.418428
# 164                      moreno, perito av. y fournier       4 -58.418428
# 173  achaval rodriguez, t., dr. av. y villaflor, az...       1 -58.358815
# 174  achaval rodriguez, t., dr. av. y villaflor, az...       1 -58.358815
# 175  achaval rodriguez, t., dr. av. y villaflor, az...       1 -58.358815
# 176                           paz, gral. av. y campana      12 -58.514523
# 177                           paz, gral. av. y campana      12 -58.514523
# 186                                                NaN       9        NaN
# 187                                                NaN       9        NaN
# 237                           paz, gral. av. y machain      12 -58.494911
# 238                           paz, gral. av. y machain      12 -58.494911
# 242                  autopista 25 de mayo y varela av.       7 -58.458074
# 243                  autopista 25 de mayo y varela av.       7 -58.458074
# 253                     riestra av. y caã‘ada de gomez       8 -58.480037
# 254                     riestra av. y caã‘ada de gomez       8 -58.480037
# 277                             rosario y la plata av.       6 -58.428553
# 278                             rosario y la plata av.       6 -58.428553
# 300                                 australia av. 2800       4 -58.386363
# 301                                 australia av. 2800       4 -58.386363
# 312     rabanal, francisco, intendente av. y saenz av.       4 -58.416578
# 313     rabanal, francisco, intendente av. y saenz av.       4 -58.416578
# 325                                 rivadavia av. 1571       1 -58.388722
# 326                                 rivadavia av. 1571       1 -58.388722
# 373                entre rios av. y garay, juan de av.       3 -58.391189
# 374                entre rios av. y garay, juan de av.       3 -58.391189
# 387                  paz, gral. av. y beron de astrada       8 -58.471994
# 388                  paz, gral. av. y beron de astrada       8 -58.471994
# 418                               paz, gral. av. 11200       9 -58.528446
# 419                               paz, gral. av. 11200       9 -58.528446
# 444                            del libertador av. 4100      14 -58.426685
# 445                            del libertador av. 4100      14 -58.426685
# 576            las heras general av. y diaz, cnel. av.      14 -58.406175
# 577            las heras general av. y diaz, cnel. av.      14 -58.406175
# 602                           nueva york y alta gracia      11 -58.527838
# 603                           nueva york y alta gracia      11 -58.527838
# 616                      san martin av. y punta arenas      15 -58.472209
# 617                      san martin av. y punta arenas      15 -58.472209
#
#        latitud    victima_1      acusado                   rol victima_2  \
# 29  -34.633504         moto       cargas             conductor      moto
# 30  -34.633504         moto       cargas  pasajero_acompañante      moto
# 98  -34.621259         auto       cargas             conductor      auto
# 99  -34.621259         auto       cargas  pasajero_acompañante      auto
# 163 -34.649791         auto  objeto fijo  pasajero_acompañante      auto
# 164 -34.649791         auto  objeto fijo             conductor      auto
# 173 -34.611136         auto  objeto fijo             conductor      auto
# 174 -34.611136         auto  objeto fijo  pasajero_acompañante      auto
# 175 -34.611136         auto  objeto fijo  pasajero_acompañante      auto
# 176 -34.581598         moto    pasajeros  pasajero_acompañante      moto
# 177 -34.581598         moto    pasajeros             conductor      moto
# 186        NaN         moto       cargas             conductor      moto
# 187        NaN         moto       cargas  pasajero_acompañante      moto
# 237 -34.547956  objeto fijo         auto  pasajero_acompañante      auto
# 238 -34.547956  objeto fijo         auto  pasajero_acompañante      auto
# 242 -34.639974         auto  objeto fijo  pasajero_acompañante      auto
# 243 -34.639974         auto  objeto fijo  pasajero_acompañante      auto
# 253 -34.681485         auto  objeto fijo  pasajero_acompañante      auto
# 254 -34.681485         auto  objeto fijo             conductor      auto
# 277 -34.618294         moto    pasajeros  pasajero_acompañante      moto
# 278 -34.618294         moto    pasajeros             conductor      moto
# 300 -34.646843         moto    pasajeros             conductor      moto
# 301 -34.646843         moto    pasajeros  pasajero_acompañante      moto
# 312 -34.654762        movil       cargas             conductor     movil
# 313 -34.654762        movil       cargas  pasajero_acompañante     movil
# 325 -34.608850       peaton         auto                peaton    peaton
# 326 -34.608850       peaton         auto                peaton    peaton
# 373 -34.627043         moto    pasajeros  pasajero_acompañante      moto
# 374 -34.627043         moto    pasajeros             conductor      moto
# 387 -34.696402         auto         auto             conductor      auto
# 388 -34.696402         auto         auto  pasajero_acompañante      auto
# 418 -34.645929         auto    pasajeros  pasajero_acompañante      auto
# 419 -34.645929         auto    pasajeros  pasajero_acompañante      auto
# 444 -34.569615       peaton         auto                peaton    peaton
# 445 -34.569615       peaton         auto                peaton    peaton
# 576 -34.583459         auto         auto             conductor      auto
# 577 -34.583459         auto         auto             conductor      auto
# 602 -34.610470  peaton_moto         moto                peaton    peaton
# 603 -34.610470  peaton_moto         moto  pasajero_acompañante      moto
# 616 -34.601114         moto         auto             conductor      moto
# 617 -34.601114         moto         auto  pasajero_acompañante      moto
#
#           sexo  edad
# 29   masculino    54
# 30   masculino     0
# 98   masculino    37
# 99   masculino    60
# 163   femenino    23
# 164  masculino    19
# 173  masculino    28
# 174  masculino    32
# 175  masculino    30
# 176   femenino     0
# 177  masculino    20
# 186  masculino    46
# 187  masculino    16
# 237  masculino    17
# 238  masculino    10
# 242  masculino     1
# 243  masculino     0
# 253  masculino    39
# 254  masculino    36
# 277  masculino     0
# 278  masculino    30
# 300  masculino    28
# 301  masculino    19
# 312  masculino    24
# 313  masculino    30
# 325   femenino    59
# 326  masculino    61
# 373   femenino    22
# 374  masculino    30
# 387  masculino    55
# 388  masculino    54
# 418  masculino    49
# 419   femenino    39
# 444  masculino     0
# 445  masculino    59
# 576  masculino    46
# 577  masculino    64
# 602  masculino    38
# 603  masculino    21
# 616   femenino    30
# 617   femenino    24
#
# Outliers en df_siniestros:
# Empty DataFrame
# Columns: [id, n_victimas, fecha, hora, tipo_de_calle, dirección normalizada, comuna, longitud, latitud, victima_1, acusado, rol, victima_2, sexo, edad]
# Index: []

# %%
# Gráfico de dispersión para los outliers en df_siniestros.
plt.figure(figsize=(10, 6))
plt.scatter(df_siniestros["edad"], range(len(df_siniestros)), color='blue', label='Víctimas')
plt.scatter(outliers_victimas["edad"], outliers_victimas.index, color='red', label='Outliers')
plt.title('Gráfico de Dispersión de Edad de Víctimas y Outliers (df_siniestros)')
plt.xlabel('Edad')
plt.ylabel('Índice')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##### En este grafico de dispersion no se pudo encontrar outliers.

# %%
# Identifico  outliers en los campos no numéricos de df_siniestros.
outliers_hechos_categorias = pd.DataFrame()

for column in df_siniestros.select_dtypes(include=['object']):

    counts = df_siniestros[column].dropna().replace('', np.nan).replace('NaN', np.nan).value_counts()
    # Identifico valores que son considerados outliers (en este caso, aquellos que aparecen muy pocas veces).
    outliers = counts[counts < 10]
    if not outliers.empty:
        outliers_hechos_categorias[column] = outliers

# Visualizar los outliers encontrados.
print("Outliers en df_siniestros:")
print(outliers_hechos_categorias)
# Out:
# Outliers en df_siniestros:
#            id  fecha  dirección normalizada  victima_1  acusado  victima_2
# id
# 2017-0035   3    NaN                    NaN        NaN      NaN        NaN
# 2017-0050   2    NaN                    NaN        NaN      NaN        NaN
# 2016-0041   2    NaN                    NaN        NaN      NaN        NaN
# 2018-0015   2    NaN                    NaN        NaN      NaN        NaN
# 2020-0063   2    NaN                    NaN        NaN      NaN        NaN
# ...        ..    ...                    ...        ...      ...        ...
# 2017-0115   1    NaN                    NaN        NaN      NaN        NaN
# 2017-0116   1    NaN                    NaN        NaN      NaN        NaN
# 2017-0118   1    NaN                    NaN        NaN      NaN        NaN
# 2017-0120   1    NaN                    NaN        NaN      NaN        NaN
# 2021-0097   1    NaN                    NaN        NaN      NaN        NaN
#
# [696 rows x 6 columns]

# %% [markdown]
# # Analisis de los campos

# %%
# Gráfico de barras para la frecuencia de valores en 'hh'.
plt.figure(figsize=(10, 6))
df_siniestros['hora'].value_counts().plot(kind='bar', color='orange')
plt.title('Frecuencia de valores en la columna "hora"')
plt.xlabel('Hora')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.show()

# Gráfico de barras para la frecuencia de valores en 'comuna'.
plt.figure(figsize=(10, 6))
df_siniestros['comuna'].value_counts().plot(kind='bar', color='green')
plt.title('Frecuencia de valores en la columna "comuna"')
plt.xlabel('Comuna')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.show()

# Gráfico de barras para la frecuencia de valores en 'victima'.
# Combina las dos columnas en una sola columna
victimas = pd.concat([df_siniestros['victima_1'], df_siniestros['victima_2']])

# Cuenta la frecuencia de valores en la columna combinada
frecuencia_victimas = victimas.value_counts()

# Combina las dos columnas en una sola columna
victimas = pd.concat([df_siniestros['victima_1'], df_siniestros['victima_2']])

# Excluye el valor 'sd' al contar la frecuencia
frecuencia_victimas = victimas[victimas != 'sd'].value_counts(dropna=False)

# Combina las dos columnas en una sola columna
victimas = pd.concat([df_siniestros['victima_1'], df_siniestros['victima_2']])

# Excluye los valores 'sd' y 'nan' al contar la frecuencia
frecuencia_victimas = victimas[(victimas != 'sd') & (~victimas.isnull())].value_counts(dropna=False)

# Grafica la frecuencia de valores en un gráfico de barras
plt.figure(figsize=(10, 6))
frecuencia_victimas.plot(kind='bar', color='purple')
plt.title('Frecuencia de valores en las columnas "victima_1" y "victima_2" (excluyendo "sd" y "nan")')
plt.xlabel('victima')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# En el primer grafico de columnas naranjas se aprecia la relacion entre la cantidad de fatalidades en funcion de la hora lo cual nos da la pauta de que la madrugada es el horario mas riesgoso.
# En el grafico de barras verdes por otro lado vemos una analisis de las fatalidades en funcion de las comunas siendo   uno, cuatro, nueve y ocho las mas elevadas en casos.
# Finalmente en el ultimo grafico de barras purpuras se aprecian las fatalidades por victimas, siendo moto y peaton las mas emblematicas.

# %% [markdown]
# ## Análisis de variables temporales.

# %%
# Importar el módulo calendar para obtener nombres de meses
import calendar

df_siniestros['fecha'] = pd.to_datetime(df_siniestros['fecha'])

# Extraigo el mes de cada fecha.
df_siniestros['mes'] = df_siniestros['fecha'].dt.month

# Convertir el mes numérico a nombre de mes
df_siniestros['nombre_mes'] = df_siniestros['fecha'].dt.month.apply(lambda x: calendar.month_name[x])

# Gráfico de barras ordenado de mayor a menor frecuencia
plt.figure(figsize=(10, 6))
df_siniestros['nombre_mes'].value_counts().sort_values(ascending=False).plot(kind='bar', color='skyblue')
plt.title('Frecuencia de valores en la columna "fecha" por mes')
plt.xlabel('Mes')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# En este grafico se ve la relacion de los accidentes en funcion de los meses ordenado de mayor a menor. Siendo Diciembre el mes mas destacado.

# %% [markdown]
# ## Análisis de género y edad de las víctimas

# %%
# Estadísticas descriptivas sobre la edad de las víctimas.
print(df_siniestros['edad'].describe())

# Gráfico de barras para la frecuencia de valores en 'edad'.
# Visualizo la distribución de la columna numérica "edad" con un histograma.
plt.figure(figsize=(10, 6))
sns.histplot(df_siniestros['edad'], bins=30, kde=True)
plt.title('Distribución de la Edad de las Víctimas')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# Calculo la distribución del género de las víctimas.
gender_distribution = df_siniestros['sexo'].value_counts()

# Visualizo la distribución del género de las víctimas como un gráfico de torta.
plt.figure(figsize=(8, 8))
gender_distribution.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Distribución del Género de las Víctimas')
plt.ylabel('')
plt.show()
# Out:
# count    717.000000
# mean      39.050209
# std       22.010669
# min        0.000000
# 25%       24.000000
# 50%       35.000000
# 75%       55.000000
# max       95.000000
# Name: edad, dtype: float64
# c:\Users\Arnaldo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Arnaldo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# En el grafico de barras de la edad se puede ver como el rango de los veinte años es el mas pronunciado.
# Y  en el grafico de torta se ve claramente que el sexo masculino es el mas impactado.

# %% [markdown]
# ## Análisis de la cantidad de víctimas por siniestro vial.

# %%
# Calculo la frecuencia de víctimas por siniestro.
frecuencia_victimas = df_siniestros['n_victimas'].value_counts()

# Visualizo distribución de víctimas por siniestro vial como gráfico de torta.
plt.figure(figsize=(8, 8))
plt.pie(frecuencia_victimas, labels=frecuencia_victimas.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Víctimas por Siniestro Vial')
plt.axis('equal')  
plt.show()

# Identifico siniestros con un alto número de víctimas.
siniestros_altas_victimas = df_siniestros[df_siniestros['n_victimas'] > 5]  # Por ejemplo, siniestros con más de 5 víctimas

# %% [markdown]
# Este grafico de torta pone de manifiesto que en la mayoria de los casos las victimas fatales son de un individuo.

# %% [markdown]
# ## Exploración de la ubicación de los siniestros viales.

# %%
plt.scatter(df_siniestros_hechos['longitud'], df_siniestros_hechos['latitud'])
plt.xlabel('Longitud')
plt.ylabel('Latitud')
plt.title('Distribución de Siniestros Viales')
plt.show()

# %% [markdown]
# El grafico hace un detalle de las ubicaciones de cada caso en la ciudad, se puede apreciar que la concentracion de los
# mismos se da en la zona de Constitucion.

# %% [markdown]
# ## Análisis de participantes y roles en los siniestros.

# %%
# Gráfico de barras para la frecuencia de valores en 'rol'
plt.figure(figsize=(10, 6))
df_siniestros['rol'].value_counts().plot(kind='bar', color='pink')
plt.title('Frecuencia de valores en la columna "rol"')
plt.xlabel('Rol')
plt.ylabel('Frecuencia')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Este grafico describe el rol de la victima durante el accidente. Es decir donde se encontraba en funcion del vehiculo.
# Se puede ver que los mas perjudicados son los roles de conductor y peaton.

# %% [markdown]
# ## Exploración de características de las calles y lugares de los siniestros.

# %%
# Calculo la frecuencia de cada tipo de calle.
frecuencia_tipo_calle = df_siniestros['tipo_de_calle'].value_counts()

# Visualizo distribución de tipos de calle como un gráfico de barras.
plt.figure(figsize=(10, 6))
frecuencia_tipo_calle.plot(kind='bar', color='skyblue')
plt.xlabel('Tipo de Calle')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Tipos de Calle')
plt.xticks(rotation=45, ha='right') 
plt.tight_layout()  
plt.show()


# Identifico características comunes de los lugares donde ocurren los siniestros.
lugares_comunes = df_siniestros_hechos['comuna'].value_counts()

# %% [markdown]
# Finalmente estudiamos el tipo de arteria donde se desembolvieron los accidentes donde la avenida es la  mas riesgosa.
