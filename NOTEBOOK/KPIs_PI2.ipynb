# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df_siniestros = pd.read_csv(r'D:\Users\Arnaldo\Desktop\SISTEMAS\SOYHENRY\CURSO\PROYECTOS\PROYECTO INDIVIDUAL II\DATASETS\df_siniestros.csv')
df_provincias = pd.read_csv(r"D:\Users\Arnaldo\Desktop\SISTEMAS\SOYHENRY\CURSO\PROYECTOS\PROYECTO INDIVIDUAL II\DATASETS\provincias.csv")

# %%
df_siniestros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717 entries, 0 to 716
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     717 non-null    object
#  1   n_victimas             717 non-null    int64
#  2   fecha                  717 non-null    object
#  3   hora                   717 non-null    int64
#  4   tipo_de_calle          717 non-null    object
#  5   dirección normalizada  708 non-null    object
#  6   comuna                 717 non-null    int64
#  7   longitud               704 non-null    float64
#  8   latitud                704 non-null    float64
#  9   victima_1              717 non-null    object
#  10  acusado                717 non-null    object
#  11  rol                    706 non-null    object
#  12  victima_2              708 non-null    object
#  13  sexo                   711 non-null    object
#  14  edad                   717 non-null    int64
# dtypes: float64(2), int64(4), object(9)
# memory usage: 84.2+ KB

# %%
df_siniestros['fecha'] = pd.to_datetime(df_siniestros['fecha'], errors='coerce')

# %%
# Lista de columnas a categorizar.
categorical_columns = ['tipo_de_calle', 'victima', 'acusado', 'rol', 'sexo','gravedad']

# Itero sobre las columnas y categorizar solo si están presentes en df_siniestros.
for column in categorical_columns:
    if column in df_siniestros.columns:
        df_siniestros[column] = df_siniestros[column].astype('category')

# %%
# Se convierte a tipo numérico con downcast a integer
df_siniestros['hora'] = pd.to_numeric(df_siniestros['hora'], errors='coerce')


df_siniestros['comuna'] = pd.to_numeric(df_siniestros['comuna'], errors='coerce')


df_siniestros['edad'] = pd.to_numeric(df_siniestros['edad'], errors='coerce')

# %% [markdown]
# Tasa de homicidios en siniestros viales y comparacion con año anterior (Objetivo reduccion del 10%)

# %%
df_siniestros
# Out:
#             id  n_victimas      fecha  hora tipo_de_calle  \
# 0    2016-0001           1 2016-01-01     4       avenida
# 1    2016-0002           1 2016-01-02     1     autopista
# 2    2016-0003           1 2016-01-03     7       avenida
# 3    2016-0004           1 2016-01-10     0       avenida
# 4    2016-0005           1 2016-01-21     5       avenida
# ..         ...         ...        ...   ...           ...
# 712  2021-0093           1 2021-12-13    17       avenida
# 713  2021-0094           1 2021-12-20     1     autopista
# 714  2021-0095           1 2021-12-30     0       avenida
# 715  2021-0096           1 2021-12-15    10       avenida
# 716  2021-0097           1 2021-11-18     6         calle
#
#                                  dirección normalizada  comuna   longitud  \
# 0    piedra buena av. y fernandez de la cruz, f., g...       8 -58.475340
# 1                 paz, gral. av. y de los corrales av.       9 -58.508775
# 2                                  entre rios av. 2034       1 -58.390403
# 3            larrazabal av. y villegas, conrado, gral.       8 -58.465039
# 4              san juan av. y saenz peã‘a, luis, pres.       1 -58.387183
# ..                                                 ...     ...        ...
# 712                                  riestra av. y mom       7 -58.433538
# 713         dellepiane, luis, tte. gral. y lacarra av.       9 -58.467398
# 714                                gaona av. y terrada      11 -58.472934
# 715                                peron, eva av. 4071       9 -58.470668
# 716                            padre carlos mugica 709       1 -58.379762
#
#        latitud  victima_1    acusado                   rol  victima_2  \
# 0   -34.687570       moto       auto             conductor       moto
# 1   -34.669777       auto  pasajeros             conductor       auto
# 2   -34.631894       moto       auto             conductor       moto
# 3   -34.680930       moto         sd             conductor       moto
# 4   -34.622466       moto  pasajeros             conductor       moto
# ..         ...        ...        ...                   ...        ...
# 712 -34.645616       moto       auto  pasajero_acompañante       moto
# 713 -34.651178       moto       auto  pasajero_acompañante       moto
# 714 -34.619847       moto     cargas             conductor       moto
# 715 -34.650217       auto     cargas             conductor       auto
# 716 -34.586796  bicicleta       auto              ciclista  bicicleta
#
#           sexo  edad
# 0    masculino    19
# 1    masculino    70
# 2    masculino    30
# 3    masculino    18
# 4    masculino    29
# ..         ...   ...
# 712   femenino    18
# 713   femenino    43
# 714  masculino    27
# 715  masculino    60
# 716  masculino    53
#
# [717 rows x 15 columns]

# %%
poblacion_CABA = 3121707

# %%
# Convertir el campo 'fecha' a datetime
df_siniestros['fecha'] = pd.to_datetime(df_siniestros['fecha'])

# Se encuentra la última fecha en tu DataFrame
ultima_fecha = df_siniestros['fecha'].max()

# Se calcula la fecha de inicio del semestre actual y anterior
semestre_actual_inicio = ultima_fecha - pd.DateOffset(months=6)
semestre_anterior_inicio = ultima_fecha - pd.DateOffset(months=12)

# Se encuentra la última fecha en tu DataFrame
ultima_fecha = df_siniestros['fecha'].max()

# Se calcula la fecha de inicio del semestre actual y anterior
semestre_actual_inicio = ultima_fecha - pd.DateOffset(months=6)
semestre_anterior_inicio = ultima_fecha - pd.DateOffset(months=12)

# Se filtra los datos para el semestre actual y anterior
datos_semestre_actual = df_siniestros[(df_siniestros['fecha'] >= semestre_actual_inicio) & (df_siniestros['fecha'] <= ultima_fecha)]
datos_semestre_anterior = df_siniestros[(df_siniestros['fecha'] >= semestre_anterior_inicio) & (df_siniestros['fecha'] <= semestre_actual_inicio)]

# Se calcula la tasa de homicidios para el semestre actual y anterior
tasa_homicidios_actual = (datos_semestre_actual['n_victimas'].sum() / poblacion_CABA) * 100000
tasa_homicidios_anterior = (datos_semestre_anterior['n_victimas'].sum() / poblacion_CABA) * 100000

# Se calcula la reducción porcentual
reduccion_porcentual = ((tasa_homicidios_anterior - tasa_homicidios_actual) / tasa_homicidios_anterior) * 100

if reduccion_porcentual >= 10:
    condicion=(f"La reduccion de tasa de homicidios en siniestros viales respecto al semestre anterior cumple con el objetivo del 10%")
else:
    condicion=(f"La reduccion de tasa de homicidios en siniestros viales respecto al semestre anterior no cumple con el objetivo del 10%")


print(f"Fecha de inicio del semestre actual: {semestre_actual_inicio}")
print(f"Fecha de inicio del semestre anterior: {semestre_anterior_inicio}")
print(f"Tasa de homicidios en siniestros viales del semestre anterior: {tasa_homicidios_anterior:.2f}")
print(f"Tasa de homicidios en siniestros viales del semestre actual: {tasa_homicidios_actual:.2f}")
print(f"Reducción porcentual: {reduccion_porcentual:.2f}%")
print(condicion)
# Out:
# Fecha de inicio del semestre actual: 2021-06-30 00:00:00
# Fecha de inicio del semestre anterior: 2020-12-30 00:00:00
# Tasa de homicidios en siniestros viales del semestre anterior: 1.76
# Tasa de homicidios en siniestros viales del semestre actual: 1.35
# Reducción porcentual: 23.64%
# La reduccion de tasa de homicidios en siniestros viales respecto al semestre anterior cumple con el objetivo del 10%

# %% [markdown]
# Accidentes mortales de motociclistas en el ultimo año, respecto al año anterior (objetivo reduccion del 7%)

# %%
# Se filtra los datos solo para motociclistas
accidentes_moto = df_siniestros[df_siniestros['n_victimas'] == 'moto']

# Se encuentra la última fecha en tu DataFrame
ultima_fecha = accidentes_moto['fecha'].max()

# Se calcula la fecha de inicio del año actual y del año anterior
anio_actual_inicio = ultima_fecha - pd.DateOffset(years=1)
anio_anterior_inicio = ultima_fecha - pd.DateOffset(years=2)

# Se filtra los datos para el último año y el año anterior
datos_anio_actual = accidentes_moto[(accidentes_moto['fecha'] >= anio_actual_inicio) & (accidentes_moto['fecha'] <= ultima_fecha)]
datos_anio_anterior = accidentes_moto[(accidentes_moto['fecha'] >= anio_anterior_inicio) & (accidentes_moto['fecha'] <= anio_actual_inicio)]

# Se cuenta la cantidad de accidentes mortales con motociclistas por año
accidentes_actual = len(datos_anio_actual)
accidentes_anterior = len(datos_anio_anterior)

if accidentes_anterior != 0:
    reduccion_porcentual = ((accidentes_anterior - accidentes_actual) / accidentes_anterior) * 100
else:
    reduccion_porcentual = 0

if reduccion_porcentual >= 7:
    condicion_moto = "La reduccion de homicidios en siniestros viales en moto respecto al año anterior cumple con el objetivo del 7%"
else:
    condicion_moto = "La reduccion de homicidios en siniestros viales en moto respecto al año anterior no cumple con el objetivo del 7%"

print(f"Fecha de inicio del año actual: {anio_actual_inicio}")
print(f"Fecha de inicio del año anterior: {anio_anterior_inicio}")
print(f"Cantidad de homicidios en moto en el año anterior: {accidentes_anterior:.2f}")
print(f"Homicidios en moto en el año actual: {accidentes_actual:.2f}")
print(f"Reducción porcentual: {reduccion_porcentual:.2f}%")
print(condicion_moto)
# Out:
# Fecha de inicio del año actual: NaT
# Fecha de inicio del año anterior: NaT
# Cantidad de homicidios en moto en el año anterior: 0.00
# Cantidad de homicidios en moto en el año actual: 0.00
# Reducción porcentual: 0.00%
# La reduccion de homicidios en siniestros viales en moto respecto al año anterior no cumple con el objetivo del 7%

# %% [markdown]
# Tasa de mortalidad en siniestros viales CABA vs provincias Argentinas (año 2019)

# %%
df_provincias['año'] = 2019

# %%
# Se crea un diccionario con los datos de la nueva fila
nueva_fila = {'Provincia': 'CABA', 'año': 2019, 'tasa_mortalidad': 2.79}

# Se convierte el diccionario en un DataFrame temporal
df_nueva_fila = pd.DataFrame([nueva_fila])

# Se concatena el DataFrame original con el DataFrame de la nueva fila
df_provincias = pd.concat([df_provincias, df_nueva_fila], ignore_index=True)

# %%
df_filtrado = df_provincias.sort_values(ascending=True, by='tasa_mortalidad',ignore_index=True)
print("Diez  provincias con tasa de mortalidad mas baja")
df_filtrado.head(10)
# Out:
# Top 10 provincias con tasa de mortalidad mas baja
#           Provincia  tasa_mortalidad   año
# 0              CABA             2.79  2019
# 1  Tierra_del_Fuego             5.30  2019
# 2        Santa_Cruz             8.40  2019
# 3            Chubut             8.50  2019
# 4           Cordoba             9.90  2019
# 5        Entre_Rios            10.10  2019
# 6         Rio_Negro            11.50  2019
# 7          La_Pampa            11.50  2019
# 8             Salta            11.70  2019
# 9         Catamarca            12.50  2019

# %%
# Convertir la columna 'fecha' a tipo fecha
df_siniestros['fecha'] = pd.to_datetime(df_siniestros['fecha'])

# Se encuentra la última fecha en tu DataFrame
ultima_fecha = df_siniestros['fecha'].max()

# Se calcula la fecha de inicio del año actual y del año anterior
anio_2020_inicio = ultima_fecha - pd.DateOffset(years=1)
anio_2019_inicio = ultima_fecha - pd.DateOffset(years=2)

# Se filtran los datos para el año 2019
datos_anio_2019 = df_siniestros[(df_siniestros['fecha'] >= anio_2019_inicio) & (df_siniestros['fecha'] <= anio_2020_inicio)]

# Se calcula la tasa de homicidios para el año 2019
tasa_homicidios_2019 = (datos_anio_2019['n_victimas'].sum() / poblacion_CABA) * 100000

# Se calcula la media de la tasa de homicidio del 2019. 
media_tasa_homicidio2019 = df_provincias['tasa_mortalidad'].mean()

# Se calcula el KPI de performance: tasa de homicidios CABA vs resto del país
tercer_kpi = (tasa_homicidios_2019 / media_tasa_homicidio2019) * 100

# Imprime los resultados
print(f"Performance tasa de homicidios CABA vs resto del país: {tercer_kpi:.2f}%")
print(f"Tasa de homicidios en siniestros viales  2019: {tasa_homicidios_2019:.2f}")
# Out:
# Performance tasa de homicidios CABA vs resto del país: 21.55%
# Tasa de homicidios en siniestros viales del 2019: 2.79

# %%
df_filtrado = df_provincias.sort_values(ascending=True, by='tasa_mortalidad',ignore_index=True)
print("Top 10 provincias con tasa de mortalidad mas baja")
df_filtrado.head(10)
# Out:
# Top 10 provincias con tasa de mortalidad mas baja
#           Provincia  tasa_mortalidad   año
# 0              CABA             2.79  2019
# 1  Tierra_del_Fuego             5.30  2019
# 2        Santa_Cruz             8.40  2019
# 3            Chubut             8.50  2019
# 4           Cordoba             9.90  2019
# 5        Entre_Rios            10.10  2019
# 6         Rio_Negro            11.50  2019
# 7          La_Pampa            11.50  2019
# 8             Salta            11.70  2019
# 9         Catamarca            12.50  2019

# %%
df_provincias.to_csv('df_provincias.csv')
